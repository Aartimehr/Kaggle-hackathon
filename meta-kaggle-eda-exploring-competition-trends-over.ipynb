# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inline
# %matplotlib inline
file_path = '/kaggle/input/meta-kaggle/Competitions.csv'
competitions_df = pd.read_csv(file_path)
competitions_df.columns = competitions_df.columns.str.strip()

# %% [markdown]
#  ## Importing Required Libraries
#
# We start by importing the necessary Python libraries for data handling, visualization, and numerical operations.

# %%
competitions_df['EnabledDate'] = pd.to_datetime(competitions_df['EnabledDate'], errors='coerce')
competitions_df['Year'] = competitions_df['EnabledDate'].dt.year

# %% [markdown]
#  Loading the Dataset
#
# We load the `Competitions.csv` file from the Meta Kaggle dataset, which contains details of all Kaggle competitions to date.

# %%
plt.figure(figsize=(12,6))
competitions_df['Year'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Number of Competitions per Year')
plt.xlabel('Year')
plt.ylabel('Number of Competitions')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#  Competitions Per Year
#
# This bar chart shows how many Kaggle competitions were hosted each year.

# %%
competitions_df['TotalTeams'] = pd.to_numeric(competitions_df['TotalTeams'], errors='coerce')
top_teams = competitions_df.sort_values('TotalTeams', ascending=False)[['Title', 'TotalTeams']].head(10)

plt.figure(figsize=(12,6))
sns.barplot(data=top_teams, y='Title', x='TotalTeams', palette='magma')
plt.title('Top 10 Competitions by Number of Teams')
plt.xlabel('Number of Teams')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Top 10 Competitions by Team Count
#
# Let's identify the competitions with the highest number of participating teams.

# %%
competitions_df.to_csv('/kaggle/working/competitions_cleaned.csv', index=False)

# %%
# Drop NaNs for rewards
rewarded = competitions_df.dropna(subset=['RewardQuantity'])

plt.figure(figsize=(12,6))
sns.histplot(rewarded['RewardQuantity'], bins=30, kde=True, color='green')
plt.title('Distribution of Competition Rewards')
plt.xlabel('Reward Amount (USD)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Prize Distribution of Competitions
#
# Analyzing how many competitions offer rewards and what kind of reward amounts are offered.

# %%
output_path = "/kaggle/working/competitions_cleaned.csv"
competitions_df.to_csv(output_path, index=False)
print("File saved at:", output_path)
# Out:
# File saved at: /kaggle/working/competitions_cleaned.csv

# %% [markdown]
# ## Exporting Cleaned Dataset
#
# We now export the cleaned dataset as a CSV file for submission to the competition.

# %% [markdown]
# ##  Dashboard Summary
#
# - **Total Competitions Analyzed**: 9716
# - **Most Active Year**: *(fill after bar chart)*
# - **Top Competition by Teams**: *(fill after bar chart)*
# - **Reward Offered in Most Competitions**: Yes, but only a fraction
# - **Insights Generated**: Competition trends, team engagement, reward dynamics
#
# ---
#
# ## Conclusion
#
# This notebook explored competition trends from the Meta Kaggle dataset.
# Key takeaways include:
#
# - Growth patterns in competition launches over the years
# - Competitions with high team participation
# - Reward-based competition patterns
